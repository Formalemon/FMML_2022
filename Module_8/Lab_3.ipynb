# %% [markdown]
# <a href="https://colab.research.google.com/github/Formalemon/FMML_2022/blob/main/Module_8/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 10:17:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   283MB/s    in 0.2s
#
# 2023-05-28 10:18:02 (283 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24271   1211.2500v1  Edge detection is one of the most critical tas...    cs
# 3865   1803.05030v1  In this paper, we present an improved feedforw...    cs
# 27539  1703.09911v1  In this paper, we propose a novel approach for...    cs
# 12973  1712.00634v1  Predictable Feature Analysis (PFA) (Richthofer...    cs
# 20535  1606.02710v1  The Vortex Search (VS) algorithm is one of the...    cs
# ...             ...                                                ...   ...
# 33519   1408.1245v4  This paper describes the Synapto-dendritic Ker...    cs
# 1009   1509.07385v3  We discuss approximation of functions using de...  stat
# 30143  1711.07828v3  The need for higher agricultural productivity ...    cs
# 11698  1610.00970v6  Stochastic optimization algorithms with varian...  stat
# 7807   1803.05045v1  Generative adversarial networks are used to ge...  stat
#
#                                                    title  year  \
# 24271  A New Algorithm Based Entropic Threshold for E...  2012
# 3865   Deep-FSMN for Large Vocabulary Continuous Spee...  2018
# 27539  Learning with Privileged Information for Multi...  2017
# 12973  PFAx: Predictable Feature Analysis to Perform ...  2017
# 20535  A Modified Vortex Search Algorithm for Numeric...  2016
# ...                                                  ...   ...
# 33519  Racing to Learn: Statistical Inference and Lea...  2014
# 1009   Provable approximation properties for deep neu...  2015
# 30143  A smartphone application to measure the qualit...  2017
# 11698  Stochastic Optimization with Variance Reductio...  2016
# 7807       Analysis of Nonautonomous Adversarial Systems  2018
#
#                                                 keywords
# 24271  [detection, automatic, universal, detection, c...
# 3865   [feedforward, sequential, architecture, introd...
# 27539  [classifiers, privileged, information, specifi...
# 12973  [predictable, algorithm, dimensionality, reduc...
# 20535  [algorithm, metaheuristic, algorithms, algorit...
# ...                                                  ...
# 33519  [describes, dendritic, statistical, inference,...
# 1009   [approximation, functions, dimensional, constr...
# 30143  [agricultural, productivity, intensive, pestic...
# 11698  [stochastic, optimization, algorithms, reducti...
# 7807   [generative, adversarial, convergence, propert...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24271    [detection, automatic, universal, detection, c...
# 3865     [feedforward, sequential, architecture, introd...
# 27539    [classifiers, privileged, information, specifi...
# 12973    [predictable, algorithm, dimensionality, reduc...
# 20535    [algorithm, metaheuristic, algorithms, algorit...
#                                ...
# 22272    [processes, hierarchical, generalisations, pro...
# 30719    [detection, algorithms, regression, prediction...
# 34354    [introduces, algorithm, automatic, summarizati...
# 27537    [monocular, viewpoint, estimation, available, ...
# 19448    [predominant, knowledge, automated, constructi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8903 words.
# Out of those 4620 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="aaba07b3-404d-4205-91e8-3a366435dd11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaba07b3-404d-4205-91e8-3a366435dd11")) {                    Plotly.newPlot(                        "aaba07b3-404d-4205-91e8-3a366435dd11",                        [{"x":["advantages","demonstrate","conditions","robustness","efficient","algorithm","threshold","automatic","computation","experimental","flexibility","thresholding","techniques","universal","detection","introducing","improvement","different","outperform","connections","sequential","applications","structure","vocabulary","vanishing","including","recognition","performance","information","lookahead","criterion","architecture","feedforward","continuous","significantly","alleviate","consistently","especially","developed","construct","advantage","dependencies","classifiers","augmented","available","classification","integrating","relationship","specifically","similarity","resolution","constraints","annotated","exploited","effectively","classifier","privileged","importance","themselves","participate","extraction","supplementary","predictable","reduction","dimensionality","prediction","multidimensional","environment","predictions","exclusively","preparing","optimization","extracted","transparently","important","reinforcement","according","improving","selection","dimensional","difficult","algorithms","solutions","increased","distribution","outperformed","benchmark","drawbacks","therefore","computational","functions","metaheuristic","simplicity","iterations","mentioned","candidate","adjustment","modification","iteration","numerical","generated","inference","formalize","accordingly","challenges","characterize","contribute","published","parallelizable","motivates","friendship","membership","community","communities","difficulty","profiling","interacts","baselines","underestimated","systematically","diffusion","developing","highlight","interpretable","approaches","increasing","methodology","resources","dimensions","variables","necessary","overfitting","representing","overlapping","particular","dependent","performing","corrupted","situation","theoretically","synthetic","probabilities","distributions","supervised","nonlinear","addresses","searching","application","structures","operations","detections","interactive","recognized","locations","likelihood","properties","correlated","population","iterative","effectiveness","challenging","characterizing","parameter","mechanism","following","subspaces","desirable","consideration","analytical","procedures","estimation","segmentation","convolutional","annotations","mammogram","traditional","diagnosis","aforementioned","specialized","assignment","superiority","probabilistic","trajectories","limitations","stationary","surroundings","processes","requiring","applicability","identifying","significance","demonstrating","environments","knowledge","influential","inflexible","technique","exploiting","canonical","minimization"],"y":[76,538,140,103,390,815,39,205,150,382,39,15,385,37,366,50,159,761,93,59,68,440,322,29,6,253,340,868,695,1,49,238,15,112,273,26,43,124,229,76,79,48,112,40,279,510,36,60,177,142,115,141,74,32,109,142,5,93,16,4,138,5,6,88,49,210,8,126,81,10,2,330,122,2,353,124,104,106,151,184,143,592,145,45,207,19,207,17,146,292,197,5,27,31,20,52,12,17,47,82,151,183,6,13,142,42,28,29,4,14,2,18,75,29,51,8,5,51,3,29,17,58,27,27,411,116,76,82,44,119,81,22,72,24,257,61,75,17,40,43,129,61,108,196,64,61,22,260,128,72,13,51,17,44,60,206,28,48,64,188,246,13,130,117,84,19,37,22,23,39,199,231,375,59,5,159,41,14,24,34,33,138,26,68,38,8,104,44,39,63,21,30,91,343,8,2,230,70,21,65],"type":"bar"},{"x":["advantages","demonstrate","conditions","robustness","efficient","algorithm","t ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4620,), (4620, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Spherical</span> <span style='background-color:rgba(0, 255, 0, 0.6140350877192982);'>Convolution</span> <span style=''>for</span> <span style=''>Fast</span> <span style=''>Features</span> <span style=''>from</span> <span style=''>360</span> <span style=''>Imagery</span> <br/><br/><span style=''>While</span> <span style=''>360deg</span> <span style=''>cameras</span> <span style=''>offer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tremendous</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>possibilities</span> <span style=''>in</span> <span style=''>vision</span> <span style=''>graphics</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>augmented</span> <span style=''>reality</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>spherical</span> <span style=''>images</span> <span style=''>they</span> <span style=''>produce</span> <span style=''>make</span> <span style=''>core</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.5771428571428572);'>extraction</span> <span style=''>non</span> <span style=''>trivial</span> <span style='background-color:rgba(0, 255, 0, 0.6094420600858368);'>Convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>images</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>cameras</span> <span style=''>yield</span> <span style=''>flat</span> <span style=''>filters</span> <span style=''>yet</span> <span style=''>360deg</span> <span style=''>images</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projected</span> <span style=''>to</span> <span style=''>a</span> <span style=''>single</span> <span style=''>plane</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.5483870967741935);'>distortion</span> <span style=''>A</span> <span style=''>naive</span> <span style=''>solution</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>repeatedly</span> <span style=''>projects</span> <span style=''>the</span> <span style=''>viewing</span> <span style=''>sphere</span> <span style=''>to</span> <span style=''>all</span> <span style=''>tangent</span> <span style=''>planes</span> <span style=''>is</span> <span style=''>accurate</span> <span style=''>but</span> <span style=''>much</span> <span style=''>too</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensive</span> <span style=''>for</span> <span style=''>real</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>spherical</span> <span style='background-color:rgba(0, 255, 0, 0.6094420600858368);'>convolutional</span> <span style=''>network</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translates</span> <span style=''>a</span> <span style=''>planar</span> <span style=''>CNN</span> <span style=''>to</span> <span style=''>process</span> <span style=''>360deg</span> <span style=''>imagery</span> <span style=''>directly</span> <span style=''>in</span> <span style=''>its</span> <span style=''>equirectangular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>learns</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>Bayesian</span> <span style=''>Models</span> <span style=''>of</span> <span style=''>Response</span> <span style=''>Function</span> <span style=''>in</span> <span style=''>Dynamic</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequences</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>task</span> <span style=''>in</span> <span style=''>dynamic</span> <span style=''>medical</span> <span style=''>imaging</span> <span style=''>This</span> <span style=''>task</span> <span style=''>arises</span> <span style=''>for</span> <span style=''>example</span> <span style=''>in</span> <span style=''>dynamic</span> <span style=''>renal</span> <span style=''>scintigraphy</span> <span style=''>where</span> <span style=''>impulse</span> <span style=''>response</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>retention</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>or</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>magnetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resonance</span> <span style=''>imaging</span> <span style=''>where</span> <span style=''>hemodynamic</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>required</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style=''>observed</span> <span style=''>directly</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>because</span> <span style=''>the</span> <span style=''>recorded</span> <span style=''>images</span> <span style=''>are</span> <span style=''>subject</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>superposition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>signals</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>the</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>via</span> <span style=''>blind</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deconvolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>heavily</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>used</span> <span style=''>models</span> <span style=''>of</span> <span style=''>the</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Lipschitz</span> <span style=''>Bandits</span> <span style=''>Regret</span> <span style=''>Lower</span> <span style=''>Bounds</span> <span style=''>and</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.31122448979591844);'>stochastic</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Lipschitz</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>arm</span> <span style=''>and</span> <span style=''>where</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>arms</span> <span style=''>is</span> <span style=''>either</span> <span style=''>discrete</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>For</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Lipschitz</span> <span style=''>bandits</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.631578947368421);'>asymptotic</span> <span style=''>problem</span> <span style=''>specific</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>regret</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>OSLB</span> <span style=''>and</span> <span style=''>CKL</span> <span style=''>UCB</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>OSLB</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.35294117647058815);'>asymptotically</span> <span style=''>optimal</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.631578947368421);'>asymptotic</span> <span style=''>regret</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>The</span> <span style=''>regret</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3658536585365854);'>concentration</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>inequality</span> <span style=''>for</span> <span style=''>weighted</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>KL</span> <span style='background-color:rgba(255, 0, 0, 0.4666666666666668);'>divergences</span> <span style=''>between</span> <span style=''>the</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Compositional</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Compositions</span> <span style=''>of</span> <span style=''>Expected</span> <span style=''>Value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>expected</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>However</span> <span style=''>they</span> <span style=''>do</span> <span style=''>not</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style=''>expected</span> <span style=''>values</span> <span style=''>or</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>composition</span> <span style=''>of</span> <span style=''>two</span> <span style=''>expected</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>ie</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>the</span> <span style=''>form</span> <span style=''>min</span> <span style=''>x</span> <span style=''>mathbfE</span> <span style=''>v</span> <span style=''>f</span> <span style=''>vbig(mathbfE</span> <span style=''>w</span> <span style=''>g</span> <span style=''>w(x)big)</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>composition</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compositional</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SCGD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>quasi</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>SCGD</span> <span style=''>update</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>noisy</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>of</span> <span style=''>f</span> <span style=''>vg</span> <span style=''>w</span> <span style=''>and</span> <span style=''>use</span> <span style=''>an</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07334525939177101)
# 	processing (0.10304114490161002)
# 	architecture (0.0851520572450805)
# 	experimental (0.1366726296958855)
# 	information (0.24865831842576028)
# 	segmentation (0.08264758497316636)
# 	recognition (0.12164579606440072)
# 	detection (0.13094812164579606)
# 	different (0.2722719141323792)
# 	convolutional (0.13416815742397137)
#
# Some Statistics words are:
# 	stochastic (0.1281795511221945)
# 	statistical (0.14463840399002495)
# 	variables (0.1341645885286783)
# 	theoretical (0.1456359102244389)
# 	algorithm (0.39251870324189525)
# 	estimation (0.17605985037406482)
# 	distribution (0.1805486284289277)
# 	dimensional (0.18902743142144637)
# 	inference (0.19401496259351622)
# 	regression (0.1765586034912718)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b505df9e-92e2-44ea-970e-b285d8a04c1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b505df9e-92e2-44ea-970e-b285d8a04c1e")) {                    Plotly.newPlot(                        "b505df9e-92e2-44ea-970e-b285d8a04c1e",                        [{"x":["advantages","demonstrate","conditions","robustness","efficient","algorithm","threshold","automatic","computation","experimental","flexibility","thresholding","techniques","universal","detection","introducing","improvement","different","outperform","connections","sequential","applications","structure","vocabulary","vanishing","including","recognition","performance","information","lookahead","criterion","architecture","feedforward","continuous","significantly","alleviate","consistently","especially","developed","construct","advantage","dependencies","classifiers","augmented","available","classification","integrating","relationship","specifically","similarity","resolution","constraints","annotated","exploited","effectively","classifier","privileged","importance","themselves","participate","extraction","supplementary","predictable","reduction","dimensionality","prediction","multidimensional","environment","predictions","exclusively","preparing","optimization","extracted","transparently","important","reinforcement","according","improving","selection","dimensional","difficult","algorithms","solutions","increased","distribution","outperformed","benchmark","drawbacks","therefore","computational","functions","metaheuristic","simplicity","iterations","mentioned","candidate","adjustment","modification","iteration","numerical","generated","inference","formalize","accordingly","challenges","characterize","contribute","published","parallelizable","motivates","friendship","membership","community","communities","difficulty","profiling","interacts","baselines","underestimated","systematically","diffusion","developing","highlight","interpretable","approaches","increasing","methodology","resources","dimensions","variables","necessary","overfitting","representing","overlapping","particular","dependent","performing","corrupted","situation","theoretically","synthetic","probabilities","distributions","supervised","nonlinear","addresses","searching","application","structures","operations","detections","interactive","recognized","locations","likelihood","properties","correlated","population","iterative","effectiveness","challenging","characterizing","parameter","mechanism","following","subspaces","desirable","consideration","analytical","procedures","estimation","segmentation","convolutional","annotations","mammogram","traditional","diagnosis","aforementioned","specialized","assignment","superiority","probabilistic","trajectories","limitations","stationary","surroundings","processes","requiring","applicability","identifying","significance","demonstrating","environments","knowledge","influential","inflexible","technique","exploiting","canonical","minimization","experiments","transforms","estimates","simulated","multivariate","predictors","alternating","formulation","effective","automatically","theoretical","simultaneously","dimension","decomposes","optimality","responses","coefficient","impossible","reasonable","convergence","regression","framework","marginals","quadratic","empirically","implementation","consistent","particles","parameters","complexity","procedure","accelerated","propagation","constructs","considering","additionally","approximating","expectation","increases","adaptively","exponential","mcallester","respectively","principal","component","meaningful","distributed","smoothing","converted","distinguish","performances","coordinate","confidence","successfully","respective","projected","statistics" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	fibrillation
# 	clarified
# 	composers
# 	periodicity
# 	nonparametrically
# 	statistician
# 	degeneracy
# 	bypassing
# 	eigendecomposition
# 	initialise
# 	initialising
# 	frobenius
# 	semiparametric
# 	nonparanormal
# 	underdetermined
# 	overdetermined
# 	covariances
# 	disentangles
# 	physician
# 	diagnosed
# Some words which never appear in Statistics papers:
# 	participate
# 	transparently
# 	friendship
# 	mammogram
# 	deductive
# 	transcribed
# 	switchboard
# 	acoustics
# 	suggestions
# 	intelligible
# 	confusing
# 	involvement
# 	misspelled
# 	abnormalities
# 	retinopathy
# 	histopathology
# 	interoperability
# 	prerequisites
# 	standards
# 	enrichment

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0703101013202333e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
