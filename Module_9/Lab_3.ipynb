# %% [markdown]
# <a href="https://colab.research.google.com/github/Formalemon/FMML_2022/blob/main/Module_9/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 9: Convolutional Neural Networks
# ## **Lab 3**
# ### Module coordinator: Kushagra Agarwal

# %% [markdown]
# ## 1. Understanding Convolutions

# %% [markdown]
# <img src="https://miro.medium.com/max/464/0*e-SMFTzO8r7skkpc" width=650px/>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing some pytorch packages
import torch
from torch.nn import Conv2d

# %% [markdown]
# Central to CNNs, a convolution operation is a linear element-wise multiplication operation between a small filter/kernel and same-sized patch from the image. We move this filter over the image like a sliding window from top left to bottom right. For each point on the image, a value is calculated based on the filter using a convolution operation. These filters can do simplest task like checking if there is a vertical line in the image or complicated task like detecting a human eye in the image.
#
# Let's look at the convolution formula:
#
# Convolution between image
# $f(x, y)$ and kernel $k(x, y)$ is
# $$f(x,y) * k(x,y) = \sum \limits _{i=0} ^{W-1} \sum \limits _{j=0} ^{H-1} f(i, j) k(x − i, y − j)$$
#
# where $W$ and $H$ are the the width and height of the image.
#
# The code demonstrates the convolution operation of a 2D matrix (image) with various filters

# %% [markdown]
# <img src="https://www.researchgate.net/profile/Chaim-Baskin/publication/318849314/figure/fig1/AS:614287726870532@1523469015098/Image-convolution-with-an-input-image-of-size-7-7-and-a-filter-kernel-of-size-3-3.png" alt="Convolution" width=650px height=280px/>

# %%
# 2D 3x3 binary image with vertical edge
image1 = np.array([[1,1,0], [1,1,0], [1,1,0]])

# 2D 3x3 binary image with horizontal edge
image2 = np.array([[0,0,0], [0,0,0], [1,1,1]])

# On plotting the images
plt.imshow(image1, cmap='gray', extent=[0, 3, 3, 0])
plt.show()
plt.imshow(image2, cmap='gray', extent=[0, 3, 3, 0])
plt.show()

# %%
# Vertical Line filter
filter = np.array([[1,0,-1],
                   [1,0,-1],
                   [1,0,-1]])

# Applying filter to first image
output = np.sum(np.multiply(image1, filter))
print('Output from first image: ', output)

# Applying filter to second image
output = np.sum(np.multiply(image2, filter))
print('Output from second image: ', output)
# Out:
# Output from first image:  3
# Output from second image:  0

# %%
# Horizontal edge filter
filter = np.array([[-1,-1,-1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]])

output = np.sum(np.multiply(image1, filter))
print('Output from first image: ', output)

output = np.sum(np.multiply(image2, filter))
print('Output from second image: ', output)
# Out:
# Output from first image:  0
# Output from second image:  3

# %% [markdown]
# Non-zero output suggests that there is a vertical edge present in the first image and not present in the second image. Similarly, horizontal edge is detected in second.

# %% [markdown]
# Let's define a function to use convolution layer from Pytorch and use our own kernel to detect edges in image

# %%
def apply_conv(image, kernel, padding=0, stride=1):

  #--------IMAGE PREPROCESSING-------
  image = torch.from_numpy(image)
  # Pytorch requires input to convolution in (N,C,H,W), where N = batch size and C=#channels in input
  input = image.view((1,1,image.shape[0], image.shape[1]))

  # --------------KERNEL-------------
  kernel = torch.from_numpy(kernel.astype(np.float32))

  # Pytorch requires kernel of shape (N,C,H,W), where N = batch size and C=#channels in input
  kernel = kernel.view((1,1,kernel.shape[0], kernel.shape[1]))

  # ---------CONVOLUTION LAYER from Pytorch--------
  conv = Conv2d(in_channels=1, out_channels=1, kernel_size=kernel.shape, padding=padding, stride=stride)

  # Set the kernel weights in the convolution layer
  conv.weight = torch.nn.Parameter(kernel)
  
  # ---------APPLY CONVOLUTION--------
  output = conv(input.float())
  output_img = output.data.numpy()  # Tensor to back in numpy
  output_img = output_img.reshape((-1, output_img.shape[-1])) # Reshape to 2D image

  return output_img

# %%
# Our original grid image
image = cv2.imread('/content/Lab_3_grid.jpg', 0)

filter = np.array([[-1,-1,-1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]])

out1 = apply_conv(image, filter, padding=0, stride=1)

filter = np.array([[1,0,-1],
                   [1,0,-1],
                   [1,0,-1]])

out2 = apply_conv(image, filter, padding=0, stride=1)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,3,1)
ax.imshow(image, cmap='gray')
ax.set_title('Original Image')
ax = fig.add_subplot(1,3,2)
ax.set_title('Horizontal edge')
ax.imshow(out1, cmap='gray')
ax = fig.add_subplot(1,3,3)
ax.imshow(out2, cmap='gray')
ax.set_title('Vertical edge')
plt.show()

# %% [markdown]
# ## Pooling Layers
#
# Pooling layers are used to reduce the dimensions of the feature maps. Thus, it reduces the number of parameters to learn and the amount of computation performed in the network. The pooling layer summarises the features present in a region of the feature map generated by a convolution layer.
#
# 1) Max Pooling:
#
# <img src='https://media.geeksforgeeks.org/wp-content/uploads/20190721025744/Screenshot-2019-07-21-at-2.57.13-AM.png' height=150px/>
#
# 2) Average Pooling:
#
# <img src='https://media.geeksforgeeks.org/wp-content/uploads/20190721030705/Screenshot-2019-07-21-at-3.05.56-AM.png' height=150px/>

# %% [markdown]
# ## Softmax layer/activation
# Recall that logistic regression produces a decimal between 0 and 1.0. For example, a logistic regression output of 0.8 from an email classifier suggests an 80% chance of an email being spam and a 20% chance of it being not spam. Clearly, the sum of the probabilities of an email being either spam or not spam is 1.0.
#
# Softmax extends this idea into a multi-class world. That is, Softmax assigns decimal probabilities to each class in a multi-class problem. Those decimal probabilities must add up to 1.0. This additional constraint helps training converge more quickly than it otherwise would.
# Softmax is implemented through a neural network layer just before the output layer. The Softmax layer must have the same number of nodes as the output layer.
#
# <img src='https://miro.medium.com/max/1400/1*ReYpdIZ3ZSAPb2W8cJpkBg.jpeg' height=170px />

# %% [markdown]
# ## Learning to train a CNN network

# %%
# Import packages
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# %%
#  Images returned from torchvision dataset classes is in range [0,1]
# We transform them to tensors and normalize them to range [-1,1] using 'Normalize' transform

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 128

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

# Classes in CIFAR10
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('Training data shape : ', trainset.data.shape, len(trainset.targets))
print('Testing data shape : ', testset.data.shape, len(testset.targets))

# Find the unique numbers from the train labels
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Training data shape :  (50000, 32, 32, 3) 50000
# Testing data shape :  (10000, 32, 32, 3) 10000
# Total number of outputs :  10
# Output classes :  ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
def train(num_epochs, model, train_loader, loss_func, optimizer):

  # Training mode
  model.train()

  train_losses = []
  train_acc = []

  # Train the model
  for epoch in range(num_epochs):
    running_loss = 0
    running_acc = 0
    for i, (images, labels) in enumerate(train_loader):
      
      # clear gradients for this training step   
      optimizer.zero_grad()           

      # Forward pass
      output = model(images)

      # Calculate loss
      loss = loss_func(output, labels)

      # Backpropagation, compute gradients 
      loss.backward()

      # Apply gradients             
      optimizer.step()                
      
      # Running loss
      running_loss += loss.item()

      # indices of max probabilities
      _, preds = torch.max(output, dim=1)

      # Calculate number of correct predictions
      correct = (preds.float() == labels).sum()
      running_acc += correct

      # Average loss and acc values 
      epoch_loss = running_loss / len(train_loader.dataset)
      epoch_acc = running_acc / len(train_loader.dataset)

    train_losses.append(epoch_loss)
    train_acc.append(epoch_acc)
    print ('Epoch {}/{}, Loss: {:.4f}, Accuracy: {:.4f}'.format(epoch + 1, num_epochs, epoch_loss, epoch_acc*100))

  return train_losses, train_acc

# %%
def test_model(model, testloader):
  correct = 0
  total = 0
  # Deactivate autograd engine (don't compute grads since we're not training)
  with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Calculate outputs by running images through the network
        outputs = model(images)
        # The class with the highest value is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

  print('Accuracy of the network: %d %%' % (
      100 * correct / total))

# %%
# CNN with 2 CONV layers and 3 FC layers
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 5)
        self.fc1 = nn.Linear(32 * 5 * 5, 512)
        self.fc2 = nn.Linear(512, 128)
        # output layer 10 classes
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        # flatten all dimensions except batch
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model = Net()
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=800, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Cross Entropy loss for multi-class classification
criterion = nn.CrossEntropyLoss()

# %%
# SGD optimizer with momentum
optimizer = optim.SGD(model.parameters(), lr=0.05, momentum=0.9)

# %%
num_epochs = 5  # iterations
train_losses, train_acc = train(num_epochs, model, trainloader, criterion, optimizer)
# Out:
# Epoch 1/5, Loss: 0.0130, Accuracy: 38.7020
# Epoch 2/5, Loss: 0.0093, Accuracy: 57.5580
# Epoch 3/5, Loss: 0.0078, Accuracy: 65.0160
# Epoch 4/5, Loss: 0.0067, Accuracy: 69.9660
# Epoch 5/5, Loss: 0.0057, Accuracy: 74.2460

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(1,2, 1)
ax.plot(np.arange(1,len(train_losses)+1),train_losses)
plt.xlabel('Training loss')
plt.ylabel('Epochs')
ax.set_title('Loss vs Epochs')
ax = fig.add_subplot(1,2, 2)
ax.plot(np.arange(1,len(train_acc)+1),train_acc)
plt.xlabel('Training accuracy')
plt.ylabel('Epochs')
ax.set_title('Accuracy vs Epochs')
plt.show()

# %%
# Accuracy on test data after training
test_model(model, testloader)
# Out:
# Accuracy of the network: 67 %

# %% [markdown]
# ## Questions
# 1) List some reasons why we should prefer CNN over ANN for image classification?
#
# 2) Try improving the CNN performance further by tuning the hyperparameters(epochs, optimizer, LR etc). Report the improved test accuracy.
#
# 3) What happens if you reduce the number of convolution layers to only 1?
#
# 4) Why didn't we use the Softmax activation in the last layer of CNN?

# %% [markdown]
# ### 1:
# - CNNs can capture the spatial and structural information in images. ANNs treat images as just a vector of pixels and lose the spatial relationships between pixels.
# - CNNs use convolutional layers and pooling layers that are specifically designed for processing image data. These layers can learn features at different levels of abstraction from low-level edges to high-level shapes.
# - Convolutional layers use weight sharing to significantly reduce the number of parameters compared to fully connected layers in ANNs. This reduced number of parameters helps avoid overfitting and allows CNNs to generalize better from smaller datasets.
# - CNNs can learn translation invariant features due to the use of convolutional and pooling layers. This means the network can detect the same features even if they appear in slightly different locations in the image.
# - CNNs are designed for multi-dimensional data like images and video. ANNs are more suitable for one-dimensional data like text.
#
# ### 2:

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 5)
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.fc1 = nn.Linear(64 * 3 * 3, 512)
        self.fc2 = nn.Linear(512, 128)
        # output layer 10 classes
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        # flatten all dimensions except batch
        x =torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 20
train_losses, train_acc = train(num_epochs, model, trainloader, criterion, optimizer)
# Out:
# Epoch 1/20, Loss: 0.0128, Accuracy: 38.7780
# Epoch 2/20, Loss: 0.0098, Accuracy: 54.3340
# Epoch 3/20, Loss: 0.0087, Accuracy: 60.2660
# Epoch 4/20, Loss: 0.0078, Accuracy: 64.3180
# Epoch 5/20, Loss: 0.0072, Accuracy: 67.4500
# Epoch 6/20, Loss: 0.0066, Accuracy: 69.9960
# Epoch 7/20, Loss: 0.0061, Accuracy: 72.2460
# Epoch 8/20, Loss: 0.0057, Accuracy: 74.2980
# Epoch 9/20, Loss: 0.0053, Accuracy: 76.1500
# Epoch 10/20, Loss: 0.0048, Accuracy: 78.3700
# Epoch 11/20, Loss: 0.0045, Accuracy: 79.6220
# Epoch 12/20, Loss: 0.0040, Accuracy: 81.9240
# Epoch 13/20, Loss: 0.0036, Accuracy: 83.6120
# Epoch 14/20, Loss: 0.0032, Accuracy: 85.3980
# Epoch 15/20, Loss: 0.0028, Accuracy: 86.9540
# Epoch 16/20, Loss: 0.0025, Accuracy: 88.7020
# Epoch 17/20, Loss: 0.0021, Accuracy: 90.3420
# Epoch 18/20, Loss: 0.0019, Accuracy: 91.6140
# Epoch 19/20, Loss: 0.0016, Accuracy: 92.4500
# Epoch 20/20, Loss: 0.0014, Accuracy: 93.5840

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(1,2, 1)
ax.plot(np.arange(1,len(train_losses)+1),train_losses)
plt.xlabel('Training loss')
plt.ylabel('Epochs')
ax.set_title('Loss vs Epochs')
ax = fig.add_subplot(1,2, 2)
ax.plot(np.arange(1,len(train_acc)+1),train_acc)
plt.xlabel('Training accuracy')
plt.ylabel('Epochs')
ax.set_title('Accuracy vs Epochs')
plt.show()

# %%
test_model(model, testloader)
# Out:
# Accuracy of the network: 68 %

# %% [markdown]
# The Test accuracy couldn't increase by a lot. Earlier it was 67% and then after some tuning, it increased by 1 to 68%. Tho, the Training accuracy reached a top of 93% in this iteration, which was previously 74%.
#
# ---
#
# ### 3:
# - The model will have less capacity. By having fewer layers, the model has less parameters it can learn and optimize. This means it will likely underfit the data and not perform as well.
# - The model will have less spatial extent of receptive fields. Since each convolutional layer captures patterns at different scales, having only 1 layer means it will only be able to detect patterns at a single scale. This limits what the model can learn from the input data.
# - The output of the convolutional layer will have fewer channels. Since both conv layers have their own set of filters, reducing to 1 layer means the output representation after the convolutional part will have fewer channels of features. This limits the information that is passed to the fully connected layers.

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16 * 15 * 15, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 20
train_losses, train_acc = train(num_epochs, model, trainloader, criterion, optimizer)
# Out:
# Epoch 1/20, Loss: 0.0116, Accuracy: 46.5800
# Epoch 2/20, Loss: 0.0088, Accuracy: 59.6320
# Epoch 3/20, Loss: 0.0075, Accuracy: 65.8940
# Epoch 4/20, Loss: 0.0064, Accuracy: 71.0040
# Epoch 5/20, Loss: 0.0056, Accuracy: 74.8940
# Epoch 6/20, Loss: 0.0046, Accuracy: 79.6160
# Epoch 7/20, Loss: 0.0036, Accuracy: 83.9720
# Epoch 8/20, Loss: 0.0027, Accuracy: 88.0480
# Epoch 9/20, Loss: 0.0020, Accuracy: 91.2320
# Epoch 10/20, Loss: 0.0014, Accuracy: 93.9300
# Epoch 11/20, Loss: 0.0011, Accuracy: 95.5840
# Epoch 12/20, Loss: 0.0009, Accuracy: 96.1380
# Epoch 13/20, Loss: 0.0007, Accuracy: 96.9500
# Epoch 14/20, Loss: 0.0005, Accuracy: 97.8900
# Epoch 15/20, Loss: 0.0006, Accuracy: 97.3640
# Epoch 16/20, Loss: 0.0006, Accuracy: 97.4920
# Epoch 17/20, Loss: 0.0005, Accuracy: 97.9840
# Epoch 18/20, Loss: 0.0004, Accuracy: 98.4140
# Epoch 19/20, Loss: 0.0005, Accuracy: 97.7680
# Epoch 20/20, Loss: 0.0004, Accuracy: 98.4320

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(1,2, 1)
ax.plot(np.arange(1,len(train_losses)+1),train_losses)
plt.xlabel('Training loss')
plt.ylabel('Epochs')
ax.set_title('Loss vs Epochs')
ax = fig.add_subplot(1,2, 2)
ax.plot(np.arange(1,len(train_acc)+1),train_acc)
plt.xlabel('Training accuracy')
plt.ylabel('Epochs')
ax.set_title('Accuracy vs Epochs')
plt.show()

# %%
test_model(model, testloader)
# Out:
# Accuracy of the network: 64 %

# %% [markdown]
# As we can notice that if we have only 1 Convolutional layer in the CNN architecture, the test accuracy of the model doesn't drop all that much. The only difference between this iteration of the model and previous iteration (as done for Question 2) is the architecture. The Model used in Question 2 had 3 CONV layers and 3 FC layers. While this here has only 1 CONV layer and 3 FC layers. Model with 3 layers had an accuracy of 68%, while with only 1 layer it has accuracy of 64%. This could potentially be because of
# - Dataset size and complexity: The CIFAR-10 dataset is relatively small and simple compared to other image classification datasets, which may limit the potential performance gain of using a more complex model architecture. In other words, the dataset may be simple enough that a simpler model architecture (with 1 convolutional layer) is able to achieve similar performance to a more complex model (with 3 convolutional layers).
# - Hyperparameter tuning: The performance of the model can be sensitive to hyperparameters such as learning rate, batch size, and regularization. It's possible that the hyperparameters used for the model with 1 convolutional layer were better suited for the dataset than when they were used for the model with 3 convolutional layers, which may have partially contributed to the similar test accuracy.
#
# Overall, this shows that it's important to consider multiple factors when evaluating the performance of a CNN model, including the dataset size, complexity, hyperparameter tuning, augmentation and regularization.
#
# <br>
#
# ---
#
# ### 4:
# - Softmax is used for classification, i.e. when the outputs represent probabilities of different classes. Since this CNN has an output size of 10, it could be used for a 10-class classification problem.
# - The loss function we would likely use is Cross Entropy Loss, which already has a softmax baked into it. Applying another softmax in the last layer would be redundant.
#
# Therefore, for these reasons we did not explicitly apply a Softmax activation to the last linear layer. The absolute outputs from the linear layer can then be fed to the Cross Entropy Loss, which will softmax the outputs and compute the loss for us.
